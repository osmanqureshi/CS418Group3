# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Offenses in each City

# %%
offense = pd.DataFrame(pd.read_excel("Data/Table_8_Offenses_Known_to_Law_Enforcement_by_State_by_City_2021.xlsx"))
offense
# Out:
#                                                 Table 8   Unnamed: 1  \
# 0                     Offenses Known to Law Enforcement          NaN
# 1                                by State by City, 2021          NaN
# 2                                                 State         City
# 3                                               ALABAMA    Abbeville
# 4                                                   NaN    Alabaster
# ...                                                 ...          ...
# 5874                                                NaN     Sheridan
# 5875                                                NaN  Thermopolis
# 5876                                                NaN   Torrington
# 5877                                                NaN      Worland
# 5878  1Limited data for 2021 were available for Cali...          NaN
#
#       Unnamed: 2      Unnamed: 3                              Unnamed: 4  \
# ...

# %%
offense = offense.drop([0, 1, 2, 5878])
offense
# Out:
#       Table 8      Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3     ALABAMA       Abbeville       2539          4          1          0
# 4         NaN       Alabaster      33963         25          1          4
# 5         NaN  Alexander City      14066         40          0          0
# 6         NaN         Altoona        913          4          0          0
# 7         NaN       Andalusia       8643         44          1          6
# ...       ...             ...        ...        ...        ...        ...
# 5873      NaN    Rock Springs      22937         49          1         17
# 5874      NaN        Sheridan      18157         15          0          0
# 5875      NaN     Thermopolis       2747          2          0          0
# 5876      NaN      Torrington       6564         16          1          4
# 5877      NaN         Worland       4947          5          0          2
#
#      Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# ...

# %%
offense = offense.rename(columns={"Table 8": "State",
                          "Unnamed: 1": "City",
                          "Unnamed: 2": "Population",
                          "Unnamed: 3": "Violent_crime",
                          "Unnamed: 4": "Murder_and_nonnegligent_manslaughter",
                          "Unnamed: 5": "Rape",
                          "Unnamed: 6": "Robbery",
                          "Unnamed: 7": "Aggravated_assault",
                          "Unnamed: 8": "Property_crime",
                          "Unnamed: 9": "Burglary",
                          "Unnamed: 10": "Larceny-theft",
                          "Unnamed: 11": "Motor_vehicle_theft",
                          "Unnamed: 12": "Arson"})
offense
# Out:
#         State            City Population Violent_crime  \
# 3     ALABAMA       Abbeville       2539             4
# 4         NaN       Alabaster      33963            25
# 5         NaN  Alexander City      14066            40
# 6         NaN         Altoona        913             4
# 7         NaN       Andalusia       8643            44
# ...       ...             ...        ...           ...
# 5873      NaN    Rock Springs      22937            49
# 5874      NaN        Sheridan      18157            15
# 5875      NaN     Thermopolis       2747             2
# 5876      NaN      Torrington       6564            16
# 5877      NaN         Worland       4947             5
#
#      Murder_and_nonnegligent_manslaughter Rape Robbery Aggravated_assault  \
# 3                                       1    0       0                  3
# 4                                       1    4       0                 20
# 5                                       0    0       7                 33
# ...

# %%
offense = offense.reset_index(drop=True)
offense
# Out:
#         State            City Population Violent_crime  \
# 0     ALABAMA       Abbeville       2539             4
# 1         NaN       Alabaster      33963            25
# 2         NaN  Alexander City      14066            40
# 3         NaN         Altoona        913             4
# 4         NaN       Andalusia       8643            44
# ...       ...             ...        ...           ...
# 5870      NaN    Rock Springs      22937            49
# 5871      NaN        Sheridan      18157            15
# 5872      NaN     Thermopolis       2747             2
# 5873      NaN      Torrington       6564            16
# 5874      NaN         Worland       4947             5
#
#      Murder_and_nonnegligent_manslaughter Rape Robbery Aggravated_assault  \
# 0                                       1    0       0                  3
# 1                                       1    4       0                 20
# 2                                       0    0       7                 33
# ...

# %%
state = ""
for index, row in offense.iterrows():
    if pd.notnull(row['State']):
        state = row['State']
    else:
        row['State'] = state
        
offense
# Out:
#         State            City Population Violent_crime  \
# 0     ALABAMA       Abbeville       2539             4
# 1     ALABAMA       Alabaster      33963            25
# 2     ALABAMA  Alexander City      14066            40
# 3     ALABAMA         Altoona        913             4
# 4     ALABAMA       Andalusia       8643            44
# ...       ...             ...        ...           ...
# 5870  WYOMING    Rock Springs      22937            49
# 5871  WYOMING        Sheridan      18157            15
# 5872  WYOMING     Thermopolis       2747             2
# 5873  WYOMING      Torrington       6564            16
# 5874  WYOMING         Worland       4947             5
#
#      Murder_and_nonnegligent_manslaughter Rape Robbery Aggravated_assault  \
# 0                                       1    0       0                  3
# 1                                       1    4       0                 20
# 2                                       0    0       7                 33
# ...

# %%
offense = offense.astype({'State':'string', 'City':'string', 'Population':'float', 'Violent_crime':'float', 'Murder_and_nonnegligent_manslaughter':'float', 'Rape':'float', 'Robbery':'float', 'Aggravated_assault':'float', 'Property_crime':'float', 'Burglary':'float', 'Larceny-theft':'float', 'Motor_vehicle_theft':'float', 'Arson':'float'})
offense.dtypes
# Out:
# State                                    string
# City                                     string
# Population                              float64
# Violent_crime                           float64
# Murder_and_nonnegligent_manslaughter    float64
# Rape                                    float64
# Robbery                                 float64
# Aggravated_assault                      float64
# Property_crime                          float64
# Burglary                                float64
# Larceny-theft                           float64
# Motor_vehicle_theft                     float64
# Arson                                   float64
# dtype: object

# %% [markdown]
# # Police in each City

# %%
police = pd.DataFrame(pd.read_excel("Data/Table_78_Full_time_Law_Enforcement_Employees_by_State_by_Cities_2021.xlsx"))
police
# Out:
#                                                Table 78   Unnamed: 1  \
# 0                   Full-time Law Enforcement Employees          NaN
# 1                                by State by City, 2021          NaN
# 2                                                 State         City
# 3                                               ALABAMA    Abbeville
# 4                                                   NaN   Adamsville
# ...                                                 ...          ...
# 8652                                                NaN  Thermopolis
# 8653                                                NaN   Torrington
# 8654                                                NaN    Wheatland
# 8655                                                NaN      Worland
# 8656  1 The employee data presented in this table fo...          NaN
#
#       Unnamed: 2                         Unnamed: 3        Unnamed: 4  \
# ...

# %%
police = police.drop([0, 1, 2, 8656])
police
# Out:
#      Table 78   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 3     ALABAMA    Abbeville       2539         10          9          1
# 4         NaN   Adamsville       4185         27         16         11
# 5         NaN      Addison        714          5          4          1
# 6         NaN    Alabaster      33963         87         69         18
# 7         NaN  Albertville      21837         67         45         22
# ...       ...          ...        ...        ...        ...        ...
# 8651      NaN     Sheridan      18157         46         29         17
# 8652      NaN  Thermopolis       2747         11          6          5
# 8653      NaN   Torrington       6564         22         15          7
# 8654      NaN    Wheatland       3512         10          9          1
# 8655      NaN      Worland       4947         13         12          1
#
# [8653 rows x 6 columns]

# %%
police = police.rename(columns={"Table 78": "State",
                          "Unnamed: 1": "City",
                          "Unnamed: 2": "Population",
                          "Unnamed: 3": "Total_law_enforcement_employees",
                          "Unnamed: 4": "Total_officers",
                          "Unnamed: 5": "Total_civilians"})
police
# Out:
#         State         City Population Total_law_enforcement_employees  \
# 3     ALABAMA    Abbeville       2539                              10
# 4         NaN   Adamsville       4185                              27
# 5         NaN      Addison        714                               5
# 6         NaN    Alabaster      33963                              87
# 7         NaN  Albertville      21837                              67
# ...       ...          ...        ...                             ...
# 8651      NaN     Sheridan      18157                              46
# 8652      NaN  Thermopolis       2747                              11
# 8653      NaN   Torrington       6564                              22
# 8654      NaN    Wheatland       3512                              10
# 8655      NaN      Worland       4947                              13
#
#      Total_officers Total_civilians
# 3                 9               1
# 4                16              11
# ...

# %%
police = police.reset_index(drop=True)
police
# Out:
#         State         City Population Total_law_enforcement_employees  \
# 0     ALABAMA    Abbeville       2539                              10
# 1         NaN   Adamsville       4185                              27
# 2         NaN      Addison        714                               5
# 3         NaN    Alabaster      33963                              87
# 4         NaN  Albertville      21837                              67
# ...       ...          ...        ...                             ...
# 8648      NaN     Sheridan      18157                              46
# 8649      NaN  Thermopolis       2747                              11
# 8650      NaN   Torrington       6564                              22
# 8651      NaN    Wheatland       3512                              10
# 8652      NaN      Worland       4947                              13
#
#      Total_officers Total_civilians
# 0                 9               1
# 1                16              11
# ...

# %%
state = ""
for index, row in police.iterrows():
    if pd.notnull(row['State']):
        state = row['State']
    else:
        row['State'] = state

police
# Out:
#         State         City Population Total_law_enforcement_employees  \
# 0     ALABAMA    Abbeville       2539                              10
# 1     ALABAMA   Adamsville       4185                              27
# 2     ALABAMA      Addison        714                               5
# 3     ALABAMA    Alabaster      33963                              87
# 4     ALABAMA  Albertville      21837                              67
# ...       ...          ...        ...                             ...
# 8648  WYOMING     Sheridan      18157                              46
# 8649  WYOMING  Thermopolis       2747                              11
# 8650  WYOMING   Torrington       6564                              22
# 8651  WYOMING    Wheatland       3512                              10
# 8652  WYOMING      Worland       4947                              13
#
#      Total_officers Total_civilians
# 0                 9               1
# 1                16              11
# ...

# %%
police = police.astype({'State':'string', 'City':'string', 'Population':'float', 'Total_law_enforcement_employees':'int', 'Total_officers':'int', 'Total_civilians':'int'})
police.dtypes
# Out:
# State                               string
# City                                string
# Population                         float64
# Total_law_enforcement_employees      int32
# Total_officers                       int32
# Total_civilians                      int32
# dtype: object

# %% [markdown]
# # Combine Tables

# %%
police_offense = pd.merge(offense, police, how='inner', on=['State', 'City'])
police_offense
# Out:
#         State            City  Population_x  Violent_crime  \
# 0     ALABAMA       Abbeville        2539.0            4.0
# 1     ALABAMA       Alabaster       33963.0           25.0
# 2     ALABAMA  Alexander City       14066.0           40.0
# 3     ALABAMA         Altoona         913.0            4.0
# 4     ALABAMA       Andalusia        8643.0           44.0
# ...       ...             ...           ...            ...
# 4927  WYOMING    Rock Springs       22937.0           49.0
# 4928  WYOMING        Sheridan       18157.0           15.0
# 4929  WYOMING     Thermopolis        2747.0            2.0
# 4930  WYOMING      Torrington        6564.0           16.0
# 4931  WYOMING         Worland        4947.0            5.0
#
#       Murder_and_nonnegligent_manslaughter  Rape  Robbery  Aggravated_assault  \
# 0                                      1.0   0.0      0.0                 3.0
# 1                                      1.0   4.0      0.0                20.0
# ...

# %%
police_offense = police_offense.drop(['Murder_and_nonnegligent_manslaughter', 'Rape', 'Robbery', 'Aggravated_assault', 'Burglary', 'Larceny-theft', 'Motor_vehicle_theft', 'Arson', 'Population_y', 'Total_officers', 'Total_civilians'], axis=1)
police_offense
# Out:
#         State            City  Population_x  Violent_crime  Property_crime  \
# 0     ALABAMA       Abbeville        2539.0            4.0            53.0
# 1     ALABAMA       Alabaster       33963.0           25.0           282.0
# 2     ALABAMA  Alexander City       14066.0           40.0           283.0
# 3     ALABAMA         Altoona         913.0            4.0             7.0
# 4     ALABAMA       Andalusia        8643.0           44.0           254.0
# ...       ...             ...           ...            ...             ...
# 4927  WYOMING    Rock Springs       22937.0           49.0           286.0
# 4928  WYOMING        Sheridan       18157.0           15.0           239.0
# 4929  WYOMING     Thermopolis        2747.0            2.0            25.0
# 4930  WYOMING      Torrington        6564.0           16.0            63.0
# 4931  WYOMING         Worland        4947.0            5.0            37.0
#
#       Total_law_enforcement_employees
# ...

# %%
police_offense['Total_crime'] = police_offense['Violent_crime'] + police_offense['Property_crime']
police_offense
# Out:
#         State            City  Population_x  Violent_crime  Property_crime  \
# 0     ALABAMA       Abbeville        2539.0            4.0            53.0
# 1     ALABAMA       Alabaster       33963.0           25.0           282.0
# 2     ALABAMA  Alexander City       14066.0           40.0           283.0
# 3     ALABAMA         Altoona         913.0            4.0             7.0
# 4     ALABAMA       Andalusia        8643.0           44.0           254.0
# ...       ...             ...           ...            ...             ...
# 4927  WYOMING    Rock Springs       22937.0           49.0           286.0
# 4928  WYOMING        Sheridan       18157.0           15.0           239.0
# 4929  WYOMING     Thermopolis        2747.0            2.0            25.0
# 4930  WYOMING      Torrington        6564.0           16.0            63.0
# 4931  WYOMING         Worland        4947.0            5.0            37.0
#
#       Total_law_enforcement_employees  Total_crime
# ...

# %%
police_offense = police_offense.drop(['Violent_crime', 'Property_crime'], axis=1)
police_offense = police_offense.rename(columns={"Population_x": "Population"})
police_offense
# Out:
#         State            City  Population  Total_law_enforcement_employees  \
# 0     ALABAMA       Abbeville      2539.0                               10
# 1     ALABAMA       Alabaster     33963.0                               87
# 2     ALABAMA  Alexander City     14066.0                               64
# 3     ALABAMA         Altoona       913.0                                3
# 4     ALABAMA       Andalusia      8643.0                               39
# ...       ...             ...         ...                              ...
# 4927  WYOMING    Rock Springs     22937.0                               46
# 4928  WYOMING        Sheridan     18157.0                               46
# 4929  WYOMING     Thermopolis      2747.0                               11
# 4930  WYOMING      Torrington      6564.0                               22
# 4931  WYOMING         Worland      4947.0                               13
#
#       Total_crime
# 0            57.0
# 1           307.0
# ...

# %%
police_offense['employees_perCapita'] = police_offense["Total_law_enforcement_employees"] / police_offense["Population"]
police_offense['crime_perCapita'] = police_offense["Total_crime"] / police_offense["Population"]
police_offense
# Out:
#         State            City  Population  Total_law_enforcement_employees  \
# 0     ALABAMA       Abbeville      2539.0                               10
# 1     ALABAMA       Alabaster     33963.0                               87
# 2     ALABAMA  Alexander City     14066.0                               64
# 3     ALABAMA         Altoona       913.0                                3
# 4     ALABAMA       Andalusia      8643.0                               39
# ...       ...             ...         ...                              ...
# 4927  WYOMING    Rock Springs     22937.0                               46
# 4928  WYOMING        Sheridan     18157.0                               46
# 4929  WYOMING     Thermopolis      2747.0                               11
# 4930  WYOMING      Torrington      6564.0                               22
# 4931  WYOMING         Worland      4947.0                               13
#
#       Total_crime  employees_perCapita  crime_perCapita
# ...

# %% [markdown]
# # Remove Outliers and Apply Regression

# %%
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.linear_model import LinearRegression

# %%
x = np.array(police_offense["employees_perCapita"])
y = np.array(police_offense["crime_perCapita"])

plt.scatter(x, y)
plt.show()

# %%
slope, intercept, r, p, std_err = stats.linregress(x.astype(float), y.astype(float))
print(slope)
def myfunc(x):
  return slope * x + intercept       # y = mx + c

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# 23.324747474809165

# %%
police_offense["employees_perCapita"] = pd.to_numeric(police_offense["employees_perCapita"])
police_offense["crime_perCapita"] = pd.to_numeric(police_offense["crime_perCapita"])
boxplot = police_offense.boxplot(column=["employees_perCapita", "crime_perCapita"])

# %%
police_offense.drop(police_offense[x>0.1].index, inplace=True)

x = np.array(police_offense["Total_law_enforcement_employees"] / police_offense["Population"])
y = np.array(police_offense["Total_crime"] / police_offense["Population"])

plt.scatter(x, y)
plt.show()

# %%
slope, intercept, r, p, std_err = stats.linregress(x.astype(float), y.astype(float))
print(slope)
def myfunc(x):
  return slope * x + intercept       # y = mx + c

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# 2.670293610246498

# %%
police_offense["employees_perCapita"] = pd.to_numeric(police_offense["employees_perCapita"])
police_offense["crime_perCapita"] = pd.to_numeric(police_offense["crime_perCapita"])
boxplot = police_offense.boxplot(column=["employees_perCapita", "crime_perCapita"])

# %%
police_offense.drop(police_offense[y>0.05].index, inplace=True)

x = np.array(police_offense["Total_law_enforcement_employees"] / police_offense["Population"])
y = np.array(police_offense["Total_crime"] / police_offense["Population"])

plt.scatter(x, y)
plt.show()

# %%
slope, intercept, r, p, std_err = stats.linregress(x.astype(float), y.astype(float))
print(slope)
def myfunc(x):
  return slope * x + intercept       # y = mx + c

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# 1.2342962209762194

# %%
police_offense["employees_perCapita"] = pd.to_numeric(police_offense["employees_perCapita"])
police_offense["crime_perCapita"] = pd.to_numeric(police_offense["crime_perCapita"])
boxplot = police_offense.boxplot(column=["employees_perCapita", "crime_perCapita"])

# %%
police_offense.drop(police_offense[x>0.005].index, inplace=True)

x = np.array(police_offense["Total_law_enforcement_employees"] / police_offense["Population"])
y = np.array(police_offense["Total_crime"] / police_offense["Population"])

plt.scatter(x, y)
plt.show()

# %%
slope, intercept, r, p, std_err = stats.linregress(x.astype(float), y.astype(float))
print(slope)
def myfunc(x):
  return slope * x + intercept       # y = mx + c

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# 3.364152405691833

# %%
police_offense["employees_perCapita"] = pd.to_numeric(police_offense["employees_perCapita"])
police_offense["crime_perCapita"] = pd.to_numeric(police_offense["crime_perCapita"])
boxplot = police_offense.boxplot(column=["employees_perCapita", "crime_perCapita"])

# %%
police_offense
# Out:
#         State            City  Population  Total_law_enforcement_employees  \
# 0     ALABAMA       Abbeville      2539.0                               10
# 1     ALABAMA       Alabaster     33963.0                               87
# 2     ALABAMA  Alexander City     14066.0                               64
# 3     ALABAMA         Altoona       913.0                                3
# 4     ALABAMA       Andalusia      8643.0                               39
# ...       ...             ...         ...                              ...
# 4927  WYOMING    Rock Springs     22937.0                               46
# 4928  WYOMING        Sheridan     18157.0                               46
# 4929  WYOMING     Thermopolis      2747.0                               11
# 4930  WYOMING      Torrington      6564.0                               22
# 4931  WYOMING         Worland      4947.0                               13
#
#       Total_crime  employees_perCapita  crime_perCapita
# ...
